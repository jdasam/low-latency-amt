# %%
import json
import os
import pandas as pd

# %%
v3_path = '/home/dasol/userdata/low-latency-transcription/onsets-and-frames/data/MAESTRO/maestro-v3.0.0.json'
v1_path = '/home/dasol/userdata/low-latency-transcription/onsets-and-frames/data/MAESTRO/maestro-v1.0.0.json'

# %%
v3_metadata = json.load(open(os.path.join(v3_path)))
v1_metadata = json.load(open(os.path.join(v1_path)))

# %%
v3_df = pd.DataFrame(v3_metadata)
v1_df = pd.DataFrame(v1_metadata)

# %%
v3_df
# Out:
#            canonical_composer                 canonical_title       split  \
# 0                  Alban Berg                    Sonata Op. 1       train
# 1                  Alban Berg                    Sonata Op. 1       train
# 2                  Alban Berg                    Sonata Op. 1       train
# 3          Alexander Scriabin   24 Preludes Op. 11, No. 13-24       train
# 4          Alexander Scriabin                3 Etudes, Op. 65  validation
# ...                       ...                             ...         ...
# 1271  Wolfgang Amadeus Mozart         Sonata in F Major, K280        test
# 1272  Wolfgang Amadeus Mozart         Sonata in F Major, K280       train
# 1273  Wolfgang Amadeus Mozart         Sonata in F Major, K533  validation
# 1274  Wolfgang Amadeus Mozart    Sonata in F Major, K533/K494  validation
# 1275  Wolfgang Amadeus Mozart  Twelve Variations, K179 (189a)       train
#
#       year                                      midi_filename  \
# ...

# %%
v1_df
# Out:
#            canonical_composer                 canonical_title  split  year  \
# 0                  Alban Berg                    Sonata Op. 1  train  2017
# 1                  Alban Berg                    Sonata Op. 1  train  2008
# 2          Alexander Scriabin   24 Preludes Op. 11, No. 13-24  train  2004
# 3          Alexander Scriabin                3 Etudes, Op. 65   test  2006
# 4          Alexander Scriabin               5 Preludes, Op.15  train  2009
# ...                       ...                             ...    ...   ...
# 1179  Wolfgang Amadeus Mozart         Sonata in F Major, K280  train  2004
# 1180  Wolfgang Amadeus Mozart         Sonata in F Major, K280  train  2004
# 1181  Wolfgang Amadeus Mozart         Sonata in F Major, K280  train  2004
# 1182  Wolfgang Amadeus Mozart         Sonata in F Major, K533  train  2004
# 1183  Wolfgang Amadeus Mozart  Twelve Variations, K179 (189a)  train  2004
#
#                                           midi_filename  \
# ...

# %%
path = 'data/MAESTRO/'
metadata = json.load(open(os.path.join(path, 'maestro-v3.0.0.json')))
metadata_df = pd.DataFrame(metadata)
files = sorted([(os.path.join(path, metadata_df.iloc[idx]['audio_filename'].replace('.wav', '.flac')),
                  os.path.join(path, metadata_df.iloc[idx]['midi_filename'])) for idx in range(len(metadata_df)) if metadata_df.iloc[idx]['split'] == 'train'])

files = [(audio if os.path.exists(audio) else audio.replace('.flac', '.wav'), midi) for audio, midi in files]

# %%
files
# Out:
# [('data/MAESTRO/2004/MIDI-Unprocessed_SMF_02_R1_2004_01-05_ORIG_MID--AUDIO_02_R1_2004_05_Track05_wav.flac',
#   'data/MAESTRO/2004/MIDI-Unprocessed_SMF_02_R1_2004_01-05_ORIG_MID--AUDIO_02_R1_2004_05_Track05_wav.midi'),
#  ('data/MAESTRO/2004/MIDI-Unprocessed_SMF_05_R1_2004_01_ORIG_MID--AUDIO_05_R1_2004_02_Track02_wav.flac',
#   'data/MAESTRO/2004/MIDI-Unprocessed_SMF_05_R1_2004_01_ORIG_MID--AUDIO_05_R1_2004_02_Track02_wav.midi'),
#  ('data/MAESTRO/2004/MIDI-Unprocessed_SMF_05_R1_2004_01_ORIG_MID--AUDIO_05_R1_2004_03_Track03_wav.flac',
#   'data/MAESTRO/2004/MIDI-Unprocessed_SMF_05_R1_2004_01_ORIG_MID--AUDIO_05_R1_2004_03_Track03_wav.midi'),
#  ('data/MAESTRO/2004/MIDI-Unprocessed_SMF_05_R1_2004_02-03_ORIG_MID--AUDIO_05_R1_2004_06_Track06_wav.flac',
#   'data/MAESTRO/2004/MIDI-Unprocessed_SMF_05_R1_2004_02-03_ORIG_MID--AUDIO_05_R1_2004_06_Track06_wav.midi'),
#  ('data/MAESTRO/2004/MIDI-Unprocessed_SMF_07_R1_2004_01_ORIG_MID--AUDIO_07_R1_2004_02_Track02_wav.flac',
# ...

# %%
files
# Out:
# [('data/MAESTRO/2004/MIDI-Unprocessed_SMF_02_R1_2004_01-05_ORIG_MID--AUDIO_02_R1_2004_06_Track06_wav.flac',
#   'data/MAESTRO/2004/MIDI-Unprocessed_SMF_02_R1_2004_01-05_ORIG_MID--AUDIO_02_R1_2004_06_Track06_wav.midi'),
#  ('data/MAESTRO/2004/MIDI-Unprocessed_SMF_02_R1_2004_01-05_ORIG_MID--AUDIO_02_R1_2004_08_Track08_wav.flac',
#   'data/MAESTRO/2004/MIDI-Unprocessed_SMF_02_R1_2004_01-05_ORIG_MID--AUDIO_02_R1_2004_08_Track08_wav.midi'),
#  ('data/MAESTRO/2004/MIDI-Unprocessed_SMF_05_R1_2004_01_ORIG_MID--AUDIO_05_R1_2004_02_Track02_wav.flac',
#   'data/MAESTRO/2004/MIDI-Unprocessed_SMF_05_R1_2004_01_ORIG_MID--AUDIO_05_R1_2004_02_Track02_wav.midi'),
#  ('data/MAESTRO/2004/MIDI-Unprocessed_SMF_05_R1_2004_01_ORIG_MID--AUDIO_05_R1_2004_03_Track03_wav.flac',
#   'data/MAESTRO/2004/MIDI-Unprocessed_SMF_05_R1_2004_01_ORIG_MID--AUDIO_05_R1_2004_03_Track03_wav.midi'),
#  ('data/MAESTRO/2004/MIDI-Unprocessed_SMF_05_R1_2004_02-03_ORIG_MID--AUDIO_05_R1_2004_06_Track06_wav.flac',
# ...

# %%
path = 'data/MAESTRO/'
metadata = json.load(open(os.path.join(path, 'maestro-v3.0.0.json')))
files = sorted([(os.path.join(path, row['audio_filename'].replace('.wav', '.flac')),
                  os.path.join(path, row['midi_filename'])) for row in metadata if row['split'] == 'train'])

files = [(audio if os.path.exists(audio) else audio.replace('.flac', '.wav'), midi) for audio, midi in files]
